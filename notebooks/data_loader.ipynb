# %% [markdown]
# # Data loader

# %%
import torch.utils.data
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
data_dir = '~/work/github/python/PestDataprocess/data/image/pest_2/train'

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                std=[0.229, 0.224, 0.225])

train_dataset = datasets.ImageFolder(
    data_dir,
    transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        normalize,
    ]))

batch_size = 8
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=False,
    num_workers=1, pin_memory=True, sampler=None)

# %%
print(f'classes:\n{train_dataset.classes}')
for i, (images, target) in enumerate(train_loader):
    print(f'i: {i}')
    print(f'image count: {len(images)}')
    print(f'target: {target}')
# Out:
# classes:
# ['beetle', 'cicadas', 'cricket', 'grasshopper']
# i: 0
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 1
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 2
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 3
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 4
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 5
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 6
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 7
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 8
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 9
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 10
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 11
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 12
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 13
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 14
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 15
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 16
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 17
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 18
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 19
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 20
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 21
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 22
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 23
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 24
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 25
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 26
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 27
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 28
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 29
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 30
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 31
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 32
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 33
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 34
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 35
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 36
# image count: 8
# target: tensor([0, 0, 0, 0, 0, 0, 0, 0])
# i: 37
# image count: 8
# target: tensor([0, 0, 0, 0, 1, 1, 1, 1])
# i: 38
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 39
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 40
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 41
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 42
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 43
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 44
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 45
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 46
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 47
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 48
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 49
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 50
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 51
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 52
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 53
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 54
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 55
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 56
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 57
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 58
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 59
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 60
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 61
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 62
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 63
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 64
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 65
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 66
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 67
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 68
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 69
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 70
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 71
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 72
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 73
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 74
# image count: 8
# target: tensor([1, 1, 1, 1, 1, 1, 1, 1])
# i: 75
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 76
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 77
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 78
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 79
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 80
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 81
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 82
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 83
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 84
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 85
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 86
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 87
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 88
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 89
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 90
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 91
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 92
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 93
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 94
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 95
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 96
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 97
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 98
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 99
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 100
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 101
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 102
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 103
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 104
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 105
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 106
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 107
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 108
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 109
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 110
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 111
# image count: 8
# target: tensor([2, 2, 2, 2, 2, 2, 2, 2])
# i: 112
# image count: 8
# target: tensor([2, 2, 2, 2, 3, 3, 3, 3])
# i: 113
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 114
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 115
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 116
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 117
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 118
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 119
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 120
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 121
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 122
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 123
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 124
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 125
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 126
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 127
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 128
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 129
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 130
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 131
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 132
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 133
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 134
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 135
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 136
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 137
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 138
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 139
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 140
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 141
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 142
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 143
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 144
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 145
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 146
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 147
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 148
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
# i: 149
# image count: 8
# target: tensor([3, 3, 3, 3, 3, 3, 3, 3])
